# %%
import pandas as pd
import numpy as np

# %%
hr_df = pd.read_csv("Desktop/Python_Udemy/original/datascienceforbusiness-master/hr_data.csv")

# %%
hr_df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
Employee_Stats_df = pd.read_excel("Desktop/Python_Udemy/original/datascienceforbusiness-master/employee_satisfaction_evaluation.xlsx")

# %%
Employee_Stats_df.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
Employee_Stats_df.describe()
# Out:
#          EMPLOYEE #  satisfaction_level  last_evaluation
# count  14999.000000        14972.000000     14972.000000
# mean   45424.627575            0.612830         0.716125
# std    25915.900127            0.248714         0.171138
# min     1003.000000            0.090000         0.360000
# 25%    22872.500000            0.440000         0.560000
# 50%    45448.000000            0.640000         0.720000
# 75%    67480.500000            0.820000         0.870000
# max    99815.000000            1.000000         1.000000

# %%
hr_df.shape
# Out:
# (14999, 9)

# %% [markdown]
# # Join the tables on Employee ID

# %%
main_df = hr_df.set_index('employee_id').join(Employee_Stats_df.set_index('EMPLOYEE #'))
main_df=main_df.reset_index()
main_df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary  \
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low
#
#    satisfaction_level  last_evaluation
# 0                0.38             0.53
# 1                0.80             0.86
# ...

# %%
#main_df.isnull()
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  average_montly_hours  time_spend_company  \
# 18            3794               2                   160                   3
# 19            1140               5                   262                   5
# 33            1230               2                   140                   3
# 53            1340               2                   132                   3
# 72           22316               2                   149                   3
# 92            1581               2                   143                   3
# 107          17376               2                   148                   3
# 120           1739               4                   158                   4
# 137           1847               2                   129                   3
# 175          32923               4                   164                   2
# 191           2160               4                   226                   6
# ...

# %%
main_df.describe()
# Out:
#         employee_id  number_project  average_montly_hours  time_spend_company  \
# count  14999.000000    14999.000000          14999.000000        14999.000000
# mean   45424.627575        3.803054            201.050337            3.498233
# std    25915.900127        1.232592             49.943099            1.460136
# min     1003.000000        2.000000             96.000000            2.000000
# 25%    22872.500000        3.000000            156.000000            3.000000
# 50%    45448.000000        4.000000            200.000000            3.000000
# 75%    67480.500000        5.000000            245.000000            4.000000
# max    99815.000000        7.000000            310.000000           10.000000
#
#        Work_accident          left  promotion_last_5years  satisfaction_level  \
# count   14999.000000  14999.000000           14999.000000        14972.000000
# mean        0.144610      0.238083               0.021268            0.612830
# ...

# %%
main_df.fillna(main_df.mean(),inplace=True)

# %%
main_df.loc[main_df.employee_id==3794]
# Out:
#     employee_id  number_project  average_montly_hours  time_spend_company  \
# 18         3794               2                   160                   3
#
#     Work_accident  left  promotion_last_5years department salary  \
# 18              1     1                      1      sales    low
#
#     satisfaction_level  last_evaluation
# 18             0.61283         0.716125

# %%
main_df.loc[0:2]
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
#
#    Work_accident  left  promotion_last_5years department  salary  \
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
#
#    satisfaction_level  last_evaluation
# 0                0.38             0.53
# 1                0.80             0.86
# 2                0.11             0.88

# %%
main_df_final = main_df.drop(columns='employee_id')

# %%
main_df_final.groupby('department').sum()
# Out:
#              number_project  average_montly_hours  time_spend_company  \
# department
# IT                     4683                248119                4256
# RandD                  3033                158030                2650
# accounting             2934                154292                2702
# hr                     2701                146828                2480
# management             2432                126787                2711
# marketing              3164                171073                3063
# product_mng            3434                180369                3135
# sales                 15634                831773               14631
# support                8479                447490                7563
# technical             10548                550793                9279
#
#              Work_accident  left  promotion_last_5years  satisfaction_level  \
# department
# IT                     164   273                      3           758.17283
# ...

# %%
main_df_final['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
category = ['department','salary']
main_df_final = pd.get_dummies(main_df_final, columns=category,drop_first=True)
main_df_final.head()
# Out:
#    number_project  average_montly_hours  time_spend_company  Work_accident  \
# 0               2                   157                   3              0
# 1               5                   262                   6              0
# 2               7                   272                   4              0
# 3               5                   223                   5              0
# 4               2                   159                   3              0
#
#    left  promotion_last_5years  satisfaction_level  last_evaluation  \
# 0     1                      0                0.38             0.53
# 1     1                      0                0.80             0.86
# 2     1                      0                0.11             0.88
# 3     1                      0                0.72             0.87
# 4     1                      0                0.37             0.52
#
#    department_RandD  department_accounting  department_hr  \
# ...

# %%
main_df_final.shape
# Out:
# (14999, 19)

# %%
len(main_df_final[main_df_final['left']==1])
# Out:
# 3571

# %%
from sklearn.model_selection import train_test_split

x =main_df_final.drop(['left'],axis=1).values
y =main_df_final['left'].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
df_train = pd.DataFrame(x_train)
df_train.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.468884  0.075186 -0.335466  2.418401 -0.145616  0.753490  0.141557
# 1  0.162450  1.239764 -0.335466  2.418401 -0.145616  1.157856  1.254458
# 2  0.162450  1.099211  0.353647 -0.413496 -0.145616  1.279165  1.078736
# 3  2.609451  1.801973  0.353647 -0.413496 -0.145616 -2.077070  1.020163
# 4 -1.468884 -1.009075 -0.335466 -0.413496 -0.145616  0.470434  1.430179
#
#           7         8        9      10       11        12        13        14  \
# 0 -0.232629 -0.235347 -0.23149 -0.2084 -0.24858 -0.255632  1.649367 -0.415074
# 1 -0.232629 -0.235347 -0.23149 -0.2084 -0.24858 -0.255632 -0.606293  2.409207
# 2 -0.232629 -0.235347 -0.23149 -0.2084 -0.24858 -0.255632 -0.606293 -0.415074
# 3 -0.232629 -0.235347 -0.23149 -0.2084 -0.24858 -0.255632 -0.606293  2.409207
# 4 -0.232629 -0.235347 -0.23149 -0.2084 -0.24858 -0.255632 -0.606293 -0.415074
#
#          15        16        17
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model =LogisticRegression(solver ='lbfgs')
model.fit(x_train,y_train)
predication= model.predict(x_test)

print('accuracy_score',round(accuracy_score(predication,y_test)*100,1))
print('confusion_matrix',confusion_matrix(y_test,predication))
print(classification_report(y_test,predication))
# Out:
# accuracy_score 78.8
# confusion_matrix [[3146  279]
#  [ 673  402]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.92      0.87      3425
#            1       0.59      0.37      0.46      1075
#
#     accuracy                           0.79      4500
#    macro avg       0.71      0.65      0.66      4500
# weighted avg       0.77      0.79      0.77      4500

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model =RandomForestClassifier()
model.fit(x_train,y_train)
predication= model.predict(x_test)

print('accuracy_score',round(accuracy_score(predication,y_test)*100,1))
print('confusion_matrix',confusion_matrix(y_test,predication))
print(classification_report(y_test,predication))
# Out:
# accuracy_score 99.0
# confusion_matrix [[3413   12]
#  [  32 1043]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3425
#            1       0.99      0.97      0.98      1075
#
#     accuracy                           0.99      4500
#    macro avg       0.99      0.98      0.99      4500
# weighted avg       0.99      0.99      0.99      4500
